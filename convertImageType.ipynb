# %%
import os
from PIL import Image
from heic2png import HEIC2PNG

def pre_process_image(folder):
    allowed_extensions = ['.png', '.jpg', '.jpeg', '.heic']

    for image_name in os.listdir(folder):
        file_path = os.path.join(folder, image_name)
        _, ext = os.path.splitext(image_name)
        ext = ext.lower()

        if ext not in allowed_extensions:
            print(f"Removing {image_name} because its extension {ext} is not allowed.")
            os.remove(file_path)
            continue

        if ext == '.heic':
            try:
                heic_img = HEIC2PNG(file_path, quality=90)
                new_file_path = os.path.splitext(file_path)[0] + ".png"
                heic_img.save(new_file_path)
                print(f"Converted {image_name} to PNG as {os.path.basename(new_file_path)}.")
            except OSError as e:
                print(f"Error converting {image_name}: {e}")
            os.remove(file_path)

        elif ext in ['.jpg', '.jpeg']:
            try:
                img = Image.open(file_path)
                new_file_path = os.path.splitext(file_path)[0] + ".png"
                img.save(new_file_path)
                print(f"Converted {image_name} to PNG as {os.path.basename(new_file_path)}.")
            except OSError as e:
                print(f"Error converting {image_name}: {e}")
            os.remove(file_path)

        else:
            # File is already a .png; no action needed
            print(f"No conversion needed for {image_name}.")


# Usage
pre_process_image(os.path.join(os.getcwd(), "Photos-001"))
# Out:
# No conversion needed for IMG_3079.png.
# No conversion needed for IMG_9742.png.
# No conversion needed for IMG_0014.png.
# No conversion needed for IMG_2005.png.
# No conversion needed for IMG_2011.png.
# No conversion needed for IMG_3119.png.
# No conversion needed for IMG_3131.png.
# No conversion needed for IMG_6048.png.
# No conversion needed for IMG_3118.png.
# No conversion needed for IMG_1069.png.
# No conversion needed for IMG_2789.png.
# No conversion needed for IMG_1243.png.
# No conversion needed for IMG_7168.png.
# No conversion needed for IMG_2010.png.
# No conversion needed for IMG_2004.png.
# No conversion needed for IMG_3291.png.
# No conversion needed for IMG_7975.png.
# No conversion needed for IMG_9743.png.
# No conversion needed for IMG_1684.png.
# No conversion needed for IMG_3078.png.
# No conversion needed for IMG_0017.png.
# No conversion needed for IMG_7988.png.
# No conversion needed for IMG_2628.png.
# No conversion needed for IMG_7977.png.
# No conversion needed for IMG_2833.png.
# No conversion needed for IMG_2012.png.
# No conversion needed for IMG_2006.png.
# No conversion needed for IMG_0639.png.
# No conversion needed for IMG_2007.png.
# No conversion needed for IMG_2013.png.
# No conversion needed for IMG_7976.png.
# No conversion needed for IMG_2629.png.
# No conversion needed for IMG_7989.png.
# No conversion needed for IMG_0228.png.
# No conversion needed for IMG_9208.png.
# No conversion needed for IMG_3094.png.
# No conversion needed for IMG_1442.png.
# No conversion needed for IMG_0012.png.
# No conversion needed for IMG_9744.png.
# No conversion needed for IMG_2836.png.
# No conversion needed for IMG_2017.png.
# No conversion needed for IMG_3877.png.
# No conversion needed for IMG_6066.png.
# No conversion needed for IMG_2214.png.
# No conversion needed for IMG_2016.png.
# No conversion needed for IMG_2837.png.
# No conversion needed for IMG_9745.png.
# No conversion needed for IMG_0013.png.
# No conversion needed for IMG_1443.png.
# No conversion needed for IMG_3095.png.
# No conversion needed for IMG_3081.png.
# No conversion needed for IMG_1643.png.
# No conversion needed for IMG_3068.png.
# No conversion needed for IMG_3097.png.
# No conversion needed for IMG_1327.png.
# No conversion needed for IMG_3295.png.
# No conversion needed for IMG_2835.png.
# No conversion needed for IMG_7965.png.
# No conversion needed for IMG_5035.png.
# No conversion needed for IMG_2014.png.
# No conversion needed for IMG_3120.png.
# No conversion needed for IMG_2216.png.
# No conversion needed for IMG_0398.png.
# No conversion needed for IMG_3875.png.
# No conversion needed for IMG_2217.png.
# No conversion needed for IMG_2015.png.
# No conversion needed for IMG_7964.PNG.
# No conversion needed for IMG_2834.png.
# No conversion needed for IMG_9746.png.
# No conversion needed for IMG_1440.png.
# No conversion needed for IMG_3069.png.
# No conversion needed for IMG_9279.png.
# No conversion needed for IMG_2112.png.
# No conversion needed for IMG_1433.png.
# No conversion needed for IMG_2847.png.
# No conversion needed for IMG_9899.png.
# No conversion needed for IMG_1221.png.
# No conversion needed for IMG_9682.png.
# No conversion needed for IMG_8013.png.
# No conversion needed for IMG_9683.png.
# No conversion needed for IMG_1432.png.
# No conversion needed for IMG_1426.png.
# No conversion needed for IMG_1183.png.
# No conversion needed for IMG_1430.png.
# No conversion needed for IMG_1424.png.
# No conversion needed for IMG_8399.png.
# No conversion needed for IMG_2844.png.
# No conversion needed for IMG_1578.png.
# No conversion needed for IMG_1222.png.
# No conversion needed for IMG_9681.png.
# No conversion needed for IMG_8762.png.
# No conversion needed for IMG_3151.png.
# No conversion needed for IMG_3178.png.
# No conversion needed for IMG_9680.png.
# No conversion needed for IMG_1579.png.
# No conversion needed for IMG_2845.png.
# No conversion needed for IMG_1425.png.
# No conversion needed for IMG_1431.png.
# No conversion needed for IMG_4213.png.
# No conversion needed for IMG_0267.png.
# No conversion needed for IMG_1810.png.
# No conversion needed for IMG_1435.png.
# No conversion needed for IMG_4217.png.
# No conversion needed for IMG_2841.png.
# No conversion needed for IMG_3381.png.
# No conversion needed for IMG_8001.png.
# No conversion needed for IMG_8015.png.
# No conversion needed for IMG_1214(1).png.
# No conversion needed for IMG_8014.png.
# No conversion needed for IMG_8766.png.
# No conversion needed for IMG_1226.png.
# No conversion needed for IMG_2840.png.
# No conversion needed for IMG_4216.PNG.
# No conversion needed for IMG_1434.png.
# No conversion needed for IMG_0258.png.
# No conversion needed for IMG_0270.png.
# No conversion needed for IMG_1807.png.
# No conversion needed for IMG_1436.png.
# No conversion needed for IMG_4214.png.
# No conversion needed for IMG_0099.png.
# No conversion needed for IMG_2842.png.
# No conversion needed for IMG_9678.png.
# No conversion needed for IMG_1218.png.
# No conversion needed for IMG_8016.png.
# No conversion needed for IMG_0476.png.
# No conversion needed for IMG_1219.png.
# No conversion needed for IMG_9679.png.
# No conversion needed for IMG_1225.png.
# No conversion needed for IMG_2738.png.
# No conversion needed for IMG_2843.png.
# No conversion needed for IMG_4215.png.
# No conversion needed for IMG_1437.png.
# No conversion needed for IMG_1423.png.
# No conversion needed for IMG_4998.png.
# No conversion needed for IMG_2696.png.
# No conversion needed for IMG_2735.png.
# No conversion needed for IMG_1214.png.
# No conversion needed for IMG_8026.png.
# No conversion needed for IMG_2085.png.
# No conversion needed for IMG_1215.png.
# No conversion needed for IMG_2046.png.
# No conversion needed for IMG_9675.png.
# No conversion needed for IMG_5107.png.
# No conversion needed for IMG_0257.png.
# No conversion needed for IMG_9273.png.
# No conversion needed for IMG_9267.png.
# No conversion needed for IMG_1439.png.
# No conversion needed for IMG_9677.png.
# No conversion needed for IMG_1217.png.
# No conversion needed for IMG_8019.png.
# No conversion needed for IMG_1983.png.
# No conversion needed for IMG_3170.png.
# No conversion needed for IMG_0479.png.
# No conversion needed for IMG_8025.png.
# No conversion needed for IMG_8024.png.
# No conversion needed for IMG_3159.png.
# No conversion needed for IMG_9306.png.
# No conversion needed for IMG_8018.png.
# No conversion needed for IMG_1216.png.
# No conversion needed for IMG_9676.png.
# No conversion needed for IMG_2051.png.
# No conversion needed for IMG_9925.png.
# No conversion needed for IMG_1438.png.
# No conversion needed for IMG_3203.png.
# No conversion needed for IMG_1400.png.
# No conversion needed for IMG_1399.png.
# No conversion needed for IMG_2848.png.
# No conversion needed for IMG_1206.png.
# No conversion needed for IMG_2733.png.
# No conversion needed for IMG_8020.png.
# No conversion needed for IMG_0482.png.
# No conversion needed for IMG_0455.png.
# No conversion needed for IMG_3376.png.
# No conversion needed for IMG_2849.png.
# No conversion needed for IMG_2691.png.
# No conversion needed for IMG_9277.png.
# No conversion needed for IMG_9275.png.
# No conversion needed for IMG_9922.png.
# No conversion needed for IMG_2693.png.
# No conversion needed for IMG_1205.png.
# No conversion needed for IMG_9329.png.
# No conversion needed for IMG_8023.png.
# No conversion needed for IMG_0481.png.
# No conversion needed for IMG_1984.png.
# No conversion needed for IMG_0640.png.
# No conversion needed for IMG_9923.png.
# No conversion needed for IMG_3201.png.
# No conversion needed for IMG_9260.png.
# No conversion needed for IMG_9207.png.
# No conversion needed for IMG_2420.png.
# No conversion needed for IMG_3070.png.
# No conversion needed for IMG_1673.png.
# No conversion needed for IMG_7982.png.
# No conversion needed for IMG_0790.png.
# No conversion needed for IMG_2839.png.
# No conversion needed for IMG_9950.png.
# No conversion needed for IMG_2024.png.
# No conversion needed for IMG_0627.png.
# No conversion needed for IMG_2018.png.
# No conversion needed for IMG_3878.png.
# No conversion needed for IMG_6041.png.
# No conversion needed for IMG_5004.png.
# No conversion needed for IMG_0626.png.
# No conversion needed for IMG_2025.png.
# No conversion needed for IMG_9951.png.
# No conversion needed for IMG_0791.png.
# No conversion needed for IMG_2838.png.
# No conversion needed for IMG_7983.png.
# No conversion needed for IMG_2623.png.
# No conversion needed for IMG_3071.png.
# No conversion needed for IMG_3067.png.
# No conversion needed for IMG_2621.png.
# No conversion needed for IMG_7981.png.
# No conversion needed for IMG_1328.png.
# No conversion needed for IMG_3265.png.
# No conversion needed for IMG_2033.png.
# No conversion needed for IMG_3113.png.
# No conversion needed for IMG_2218.png.
# No conversion needed for IMG_6042.png.
# No conversion needed for IMG_2740.png.
# No conversion needed for IMG_9952.png.
# No conversion needed for IMG_0792.png.
# No conversion needed for IMG_7980.png.
# No conversion needed for IMG_3066.png.
# No conversion needed for IMG_1675.png.
# No conversion needed for IMG_3076.png.
# No conversion needed for IMG_7984.png.
# No conversion needed for IMG_7990.png.
# No conversion needed for IMG_3300.png.
# No conversion needed for IMG_2022.png.
# No conversion needed for IMG_6052.png.
# No conversion needed for IMG_6047.png.
# No conversion needed for IMG_6053.png.
# No conversion needed for IMG_3117.png.
# No conversion needed for IMG_2023.png.
# No conversion needed for IMG_2631.png.
# No conversion needed for IMG_7985.png.
# No conversion needed for IMG_4903.png.
# No conversion needed for IMG_3077.png.
# No conversion needed for IMG_1674.png.
# No conversion needed for IMG_0226.png.
# No conversion needed for IMG_0583.png.
# No conversion needed for IMG_0018.png.
# No conversion needed for IMG_7987.png.
# No conversion needed for IMG_7978.png.
# No conversion needed for IMG_2196.png.
# No conversion needed for IMG_2009.png.
# No conversion needed for IMG_2021.png.
# No conversion needed for IMG_2790.png.
# No conversion needed for IMG_3101.png.
# No conversion needed for IMG_1716.png.
# No conversion needed for IMG_1717.png.
# No conversion needed for IMG_2034.png.
# No conversion needed for IMG_2020.png.
# No conversion needed for IMG_2008.png.
# No conversion needed for IMG_7979.png.
# No conversion needed for IMG_7986.png.
# No conversion needed for IMG_0019.png.
# No conversion needed for IMG_0582.png.
# No conversion needed for IMG_0227.png.
# No conversion needed for IMG_3074.png.
