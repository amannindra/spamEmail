# %%
import kagglehub

import numpy as np
from torch import nn
from PIL import Image, ImageOps
import cv2
import torch
import pandas as pd
import torch.nn as nn
import torch.nn.functional as F
import torchvision.transforms as transforms
import torchvision.models as models
from tensorflow.keras.preprocessing import image
import matplotlib.pyplot as plt
from torch.utils.data import DataLoader
from torchvision import datasets
import matplotlib.image as mpimg
from IPython.display import display

import yfinance as yf


import os
from keras.applications.vgg16 import VGG16
import kagglehub

# %%
path = kagglehub.dataset_download("kazanova/sentiment140")

print("Path to dataset files:", path)

path = os.path.join(path, "train.csv")
# Out:
# Path to dataset files: /Users/aman/.cache/kagglehub/datasets/kazanova/sentiment140/versions/2

# %%
df = pd.read_csv(path, encoding='ISO-8859-1',  names=['target', 'id', 'date', 'flag', 'user', 'text'], 
                 header=None)

info = df.info()

# print(info)
print("-----------------")

s = 0
for i in range(round(len(df["text"])/100    )):
    df.loc[i, "text"] = df.loc[i, "text"].lower()
    print(df.loc[i, "text"])

display(df["text"].head(5))
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1600000 entries, 0 to 1599999
# Data columns (total 6 columns):
#  #   Column  Non-Null Count    Dtype
# ---  ------  --------------    -----
#  0   target  1600000 non-null  int64
#  1   id      1600000 non-null  int64
#  2   date    1600000 non-null  object
#  3   flag    1600000 non-null  object
#  4   user    1600000 non-null  object
#  5   text    1600000 non-null  object
# dtypes: int64(2), object(4)
# memory usage: 73.2+ MB
# -----------------
# @switchfoot http://twitpic.com/2y1zl - awww, that's a bummer.  you shoulda got david carr of third day to do it. ;d
# is upset that he can't update his facebook by texting it... and might cry as a result  school today also. blah!
# @kenichan i dived many times for the ball. managed to save 50%  the rest go out of bounds
# my whole body feels itchy and like its on fire
# @nationwideclass no, it's not behaving at all. i'm mad. why am i here? because i can't see you all over there.
# ...

# %%
ticker = "AAPL"

ticker = yf.Ticker(ticker)

historical_data = ticker.history(period ="10y")
print("Historical Data:")
print(historical_data)
# Out:
# ---------------------------------------------------------------------------
# YFRateLimitError                          Traceback (most recent call last)
# Cell In[4], line 5
#       1 ticker = "AAPL"
#       3 ticker = yf.Ticker(ticker)
# ----> 5 historical_data = ticker.history(period ="10y")
#       6 print("Historical Data:")
#       7 print(historical_data)
#
# File ~/.pyenv/versions/3.11.6/lib/python3.11/site-packages/yfinance/utils.py:104, in log_indent_decorator.<locals>.wrapper(*args, **kwargs)
#     101 logger.debug(f'Entering {func.__name__}()')
#     103 with IndentationContext():
# --> 104     result = func(*args, **kwargs)
#     106 logger.debug(f'Exiting {func.__name__}()')
#     107 return result
#
# File ~/.pyenv/versions/3.11.6/lib/python3.11/site-packages/yfinance/base.py:81, in TickerBase.history(self, *args, **kwargs)
#      79 @utils.log_indent_decorator
#      80 def history(self, *args, **kwargs) -> pd.DataFrame:
# ...
